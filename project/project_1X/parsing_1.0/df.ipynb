# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly
import plotly.express as px

from sklearn import linear_model
from sklearn import tree
from sklearn import ensemble
from sklearn import metrics
from sklearn import preprocessing
from sklearn.model_selection import train_test_split

# %%
Bundes_liga_19_20 = pd.read_csv("../parsing_2.0/data_auto/Bundes_lige2019-2020.csv")

# %%
Bundes_liga_19_20
# Out:
#      Unnamed: 0.1  Unnamed: 0        id  \
# 0             308         308  14898402
# 1             309         309  14898401
# 2             310         310  14898392
# 3             311         311  14898393
# 4             312         312  14898394
# ..            ...         ...       ...
# 303           611         611  14898097
# 304           612         612  14898099
# 305           613         613  14898101
# 306           614         614  14898102
# 307           615         615  14898095
#
#                                       общая информация              Дата  \
# 0         Бундеслига, стыковые матчи, 06.07.2020 21:30  06.07.2020 21:30
# 1         Бундеслига, стыковые матчи, 02.07.2020 21:30  02.07.2020 21:30
# 2    Бундеслига, 34-й тур, регулярный сезон, 27.06....  27.06.2020 16:30
# 3    Бундеслига, 34-й тур, регулярный сезон, 27.06....  27.06.2020 16:30
# 4    Бундеслига, 34-й тур, регулярный сезон, 27.06....  27.06.2020 16:30
# ...

# %% [markdown]
# CONTACT INFORMATION:
# Telegram:
# WhatsApp: +79585135702
# Email address: ahper17052000@gmail.com
# LinkedIn: https://www.linkedin.com/in/gor36
# GOR AMBARTSUMIAN
# Objective:
#
#
# I am a novice Data Scientist and Data Analysist. I am eager to
# work and gain new experience on AI and ML.
#
# SKILLS
# Programming languages: Python, SQL
# Machine Learning Frameworks: Scikit-learn,
# Data visualization tools: Google charts, Plotly, Matplotlib,
# Seaborn.
#
# EDUCATION
# Military Educational and Scientific Center of Air force named
# after Zhukovsky and Gagarin, Voronezh, Russia — Air Engineer
# September 2018 - May 2023
#
# SkillFactory courses from Moscow State University - Data
# Scientist
# October 2022 - present
#
# PROJECTS
# Banking analysis - Jan. 2023 - Feb. 2023
# Link: https://github.com/Gor36/Project_1
#
#
#
# WORKSHOPS
# ● Listened to webinars about AutoML from Moscow State
# University;
# ● Made some projects in Kaggle
#
# LANGUAGES
# ● Russian(native)
# ● Armenian(native)
# ● English(B1)
# ● Spanish(A1)
#
# REFERENCES:
# References available upon request
