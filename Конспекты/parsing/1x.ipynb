# %%
import pandas as pd
import urllib.parse as req
import requests
from bs4 import BeautifulSoup

path_common = req.urlparse('https://1xstavka.ru/line/football/96463-germany-bundesliga')
url = path_common.scheme + '://' + req.quote(path_common.netloc) +  req.quote(path_common.path) + '#'+ req.quote(path_common.fragment)
response = requests.get(url) # Выполняем GET-запрос, содержимое ответа присваивается переменной response
#tables = pd.read_html(response)

tables = pd.read_html('https://soccer365.ru/games/1737094/')

# %%
tables = pd.read_html('https://soccer365.ru/competitions/17/')

# %%
tables[0]
# Out:
#     Unnamed: 0          Unnamed: 1   И   В   Н   П   З  П.1  +/-   О
# 0            1   Боруссия Дортмунд  30  19   4   7  67   40   27  61
# 1            2             Бавария  29  17   8   4  79   33   46  59
# 2            3        Унион Берлин  30  16   8   6  44   31   13  56
# 3            4            Фрайбург  30  16   8   6  46   37    9  56
# 4            5          РБ Лейпциг  30  16   6   8  54   37   17  54
# 5            6               Байер  30  14   6  10  53   41   12  48
# 6            7               Майнц  29  12   9   8  49   40    9  45
# 7            8          Вольфсбург  29  11  10   8  51   37   14  43
# 8            9  Айнтрахт Франкфурт  30  11  10   9  50   46    4  43
# 9           10          Боруссия М  30   9   9  12  44   48   -4  36
# 10          11               Кёльн  30   8  11  11  40   48   -8  35
# 11          12              Вердер  30  10   5  15  48   58  -10  35
# 12          13            Аугсбург  30   8   7  15  39   55  -16  31
# 13          14          Хоффенхайм  30   8   5  17  39   51  -12  29
# 14          15            Штутгарт  30   6  10  14  38   52  -14  28
# 15          16               Бохум  30   8   4  18  33   67  -34  28
# 16          17              Шальке  30   6   9  15  28   57  -29  27
# 17          18               Герта  29   5   7  17  35   59  -24  22
